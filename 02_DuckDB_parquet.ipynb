# %%
import duckdb

conn = duckdb.connect()

query = """
    SELECT *
    FROM 'data/yellow_trip_data/*.parquet'
    --LIMIT 10
"""

df = conn.sql(query).df()
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 5443357         2  2022-02-28 23:50:00   2022-03-01 00:06:00              NaN
# 5443358         2  2022-02-28 23:06:57   2022-02-28 23:19:12              NaN
# 5443359         2  2022-02-28 23:48:13   2022-03-01 00:03:33              NaN
# 5443360         2  2022-02-28 23:56:41   2022-03-01 00:04:57              NaN
# 5443361         2  2022-02-28 23:04:00   2022-02-28 23:10:00              NaN
#
# ...

# %%
# Prima crea una tabella permanente dal DataFrame
conn.execute("CREATE TABLE IF NOT EXISTS my_table AS SELECT * FROM df")

# Poi crea la vista basata sulla tabella
conn.execute("CREATE VIEW IF NOT EXISTS df_view AS SELECT * FROM my_table")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
import duckdb

query2 = """SELECT * 
            FROM df_view 
            
        """
df = conn.execute(query2).df()
df
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[9], line 7
#       1 import duckdb
#       3 query2 = """SELECT *
#       4             FROM df_view
#       5
#       6         """
# ----> 7 df = conn.execute(query2).df()
#       8 df
#
# CatalogException: Catalog Error: Table with name df_view does not exist!
# Did you mean "pg_views"?
# LINE 2:             FROM df_view
#                          ^

# %%
conn.close()
